# %% [markdown]
# <h1 style="font-size:30px;">Learn How to use Keras for Modeling Linear Regression</h1>
#
# Before studying deep neural networks, we will cover the fundamental components of a simple (linear) neural network. We'll begin with the topic of linear regression. Since linear regression can be modeled as a neural network, it provides an excellent example to introduce the essential components of neural networks. Regression is a form of supervised learning which aims to model the relationship between one or more input variables (features) and a continuous (target) variable. We assume that the relationship between the input variables $x$ and the target variable $y$ can be expressed as a weighted sum of the inputs (i.e., the model is linear in the parameters). In short, linear regression aims to learn a function that maps one or more input features to a single numerical target value.
#
# <img src='https://learnopencv.com/wp-content/uploads/2023/01/keras-linear-regression-model-plot.png' width=1000 align='center'><br/>
#
#
#
# ## Table of Contents
# * [1 Dataset Exploration](#1-Dataset-Exploration)
# * [2 Linear Regression Model](#2-Linear-Regression-Model)
# * [3 Neural Network Perspective and Terminology](#3-Neural-Network-Perspective-and-Terminology)
# * [4 Modeling a Neural Network in Keras](#4-Modeling-a-Neural-Network-in-Keras)
# * [5 Conclusion](#5-Conclusion)

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Activation
from tensorflow.keras.datasets import boston_housing
from tensorflow.keras import layers

import tensorflow as tf
import matplotlib.pyplot as plt

# %%
SEED_VALUE = 42

# Fix seed to make training deterministic.
np.random.seed(SEED_VALUE)
tf.random.set_seed(SEED_VALUE)

# %% [markdown]
# # 1 Dataset Exploration
#
# ## 1.1 Load the Boston Housing Dataset
# In this notebook, we will be working with the Boston Housing dataset. This dataset contains information collected by the U.S Census Service concerning housing in Boston MA. It has been used extensively throughout the literature to benchmark algorithms and is also suitable for demonstration purposes due to its small size. The dataset contains 14 unique attributes, among which is the median value (price in $K) of a home for a given suburb. We will use this dataset as an example of how to develop a model that allows us to predict the median price of a home based on a single attribute in the dataset (average number of rooms in a house).
#
# Keras provides the `load_data()` function to load this dataset. Datasets are typically partitioned into `train`, and `test` components, and the `load_data()` function returns a tuple for each. Each tuple contains a 2-dimensional array of features (e.g., X_train) and a vector that contains the associated target values for each sample in the dataset (e.g., y_train). So, for example, the rows in `X_train` represent the various samples in the dataset and the columns represent the various features. In this notebook, we are only going to make use of the training data to demonstrate how to train a model. However, in practice, it is very important to use the test data to see how well the trained model performs on unseen data.

# %%
# Load the Boston housing dataset.
(X_train, y_train), (X_test, y_test) = boston_housing.load_data()

print(X_train.shape)
print("\n")
print("Input features: ", X_train[0])
print("\n")
print("Output target: ", y_train[0])
# Out:
# (404, 13)
#
#
# Input features:  [  1.23247   0.        8.14      0.        0.538     6.142    91.7
#    3.9769    4.      307.       21.      396.9      18.72   ]
#
#
# Output target:  15.2

# %% [markdown]
# ## 1.2 Extract Features from the Dataset
#
# In this notebook we are only going to use a single feature from the dataset, so to keep things simple, we will store the feature data in a new variable.

# %%
COLUMN = 5

X_train_1d = X_train[:, COLUMN]
print(X_train_1d.shape)

X_test_1d = X_test[:, COLUMN]
print(X_test_1d.shape)
# Out:
# (404,)
# (102,)

# %% [markdown]
# ## 1.3 Plot the Features
# Here we plot the median price of a home vs. the single feature ('Average Number of Rooms').

# %%
plt.figure(figsize=(15, 5))

plt.xlabel('Average Number of Rooms')
plt.ylabel('Median Price [$K]')
plt.grid("on")
plt.scatter(X_train_1d[:], y_train, color='green', alpha=0.5)
plt.show()

# %% [markdown]
# ## 2 Linear Regression Model
#
# Let's first start with a clear picture of what we are trying to accomplish. The plot below shows the training data for the single independent variable (number of rooms) and the dependent variable (the median price of a house). We would like to use linear regression to develop a reliable model for this data. In this example, the model is simply a straight line defined by its slope ($m$) and y-intercept ($b$).
#
# <img src='https://learnopencv.com/wp-content/uploads/2023/01/keras-linear-regression-model-plot.png' width=1000 align='center'><br/>

# %% [markdown]
# ## 3 Neural Network Perspective and Terminology
#
# The figure below shows how this model can be represented as a simple (single neuron) network. We will use this simple example to introduce neural network components and terminology. The input data ($x$) consists of a single feature (average number of rooms), and the predicted output ($y'$) is a scalar (predicted median price of a home). Note that each data sample in the dataset represents the statistics for a Boston suburb. The model parameters ($m$ and $b$), are learned iteratively during the training process. As you may already know, the model parameters can be computed by the method of Ordinary Least Squares (OSL) in the closed form. However, we can also solve this problem iteratively using a numerical technique called **Gradient Descent**, which is the basis for how neural networks are trained. We will not cover the details of gradient descent in this notebook, but it's important to understand that it's an iterative technique that is used to tune the parameters of the model.
#
#  <img src='https://learnopencv.com/wp-content/uploads/2023/01/keras-linear-regression-forward-pass-block-diagram.png' width=700 align='center'><br/>
#
# The network contains just a single neuron that takes a single input ($x$) and produces a single output ($y'$) which is the predicted (average) price of a home. The single neuron has two trainable parameters, which are the slope ($m$) and y-intercept ($b$) of the linear model. These parameters are more generally known as the weight and bias, respectively. In regression problems, it is common for the model to have multiple input features, where each input has an associated weight ($w_i$), but in this example, we will use just a single input feature to predict the output. So, in general, a neuron typically has multiple weights ($w_1$, $w_2$, $w_3$, etc.) and a single bias term ($b$). In this example, you can think of the neuron as the mathematical computation of $mx + b$, which produces the predicted value $y'$.
#
# A slightly more formal diagram is shown below for the same model. Here we have now introduced the concept of a **feedback loop** that shows how model parameters ($w$ and $b$) are updated during the training process. Initially, the model parameters are initialized to small random values. During the training process, as training data is passed through the network, the predicted value of the model ($y'$) is compared to the ground truth ($y$) for a given sample from the dataset. The difference is used as the basis to compute a **loss** which is then used as feedback in the network to adjust the model parameters in a way that improves the prediction. This process involves two steps called **Gradient Descent** and **Backpropagation**. It's not important at this stage to understand the mathematical details of how this works, but it is important to understand that there is an iterative process to training the model.
#
#  <img src='https://learnopencv.com/wp-content/uploads/2023/01/keras-linear-regression-weight-update-block-diagram.png' width=700 align='center'><br/>
#
#
# The **Loss Function** we use can take many forms. For this example, we will use **Mean Squared Error (MSE)** which is a very common loss function used in regression problems.
#
# $$ J = \frac{1}{m}\sum_{i=1}^{m} (y_{i}' - y_{i})^2 $$
#
# The basic idea is that we want to minimize the value of this function which is a representation of the error between our model and the training dataset. In the equation above, $m$ is the number of training samples.

# %% [markdown]
# ## 4 Modeling a Neural Network in Keras
# The network diagram in the previous section represents the simplest possible neural network. The network has a single layer consisting of a single neuron that outputs $wx+b$. For every training sample, the predicted output $y'$ is compared to the actual value from the training data, and the loss is computed. The loss can then be used to fine-tune (update) the model parameters.
#
# All of the details associated with training a neural network are taken care of by Keras as summarized in the following workflow:
#
# 1. Build/Define a network model using predefined layers in Keras.
# 2. Compile the model with `model.compile()`
# 3. Train the model with `model.fit()`
# 4. Predict the output `model.predict()`

# %% [markdown]
# ### 4.1 Define the Keras Model

# %%
model = Sequential()

# Define the model consisting of a single neuron.
# model.add(Dense(units=1, input_shape=(1,)))
model.add(Input(shape=(1,)))  # Equivalent to the above line, this is a more explicit way to define the input layer.
model.add(Dense(units=1)) 

# Display a summary of the model architecture.
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 4.2 Compile the Model

# %%
# and save the accuracy and loss in the history object
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.005),
              loss='mse', 
                metrics=['mse', 'accuracy'])

# %% [markdown]
# ### 4.3 Train the Model

# %%
# train the model 
history = model.fit(X_train_1d, 
                    y_train, 
                    batch_size=16, # Number of samples per gradient update.
                    epochs=101,  # An epoch is an iteration over the entire x and y data provided.
                    validation_split=0.3,
                    verbose=1)
# Out:
# Epoch 1/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0000e+00 - loss: 508.6873 - mse: 508.9674 - val_accuracy: 0.0000e+00 - val_loss: 610.2413 - val_mse: 622.1050
# Epoch 2/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 474.7621 - mse: 475.0280 - val_accuracy: 0.0000e+00 - val_loss: 580.0950 - val_mse: 591.5819
# Epoch 3/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 448.5189 - mse: 448.7779 - val_accuracy: 0.0000e+00 - val_loss: 551.7293 - val_mse: 562.8563
# Epoch 4/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 423.6545 - mse: 423.9073 - val_accuracy: 0.0000e+00 - val_loss: 524.3363 - val_mse: 535.1103
# Epoch 5/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 399.6917 - mse: 399.9385 - val_accuracy: 0.0000e+00 - val_loss: 497.8034 - val_mse: 508.2301
# Epoch 6/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 376.5627 - mse: 376.8035 - val_accuracy: 0.0000e+00 - val_loss: 472.1134 - val_mse: 482.1981
# Epoch 7/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 354.2565 - mse: 354.4915 - val_accuracy: 0.0000e+00 - val_loss: 447.2633 - val_mse: 457.0116
# Epoch 8/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 332.7708 - mse: 333.0000 - val_accuracy: 0.0000e+00 - val_loss: 423.2520 - val_mse: 432.6692
# Epoch 9/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 312.1043 - mse: 312.3277 - val_accuracy: 0.0000e+00 - val_loss: 400.0789 - val_mse: 409.1704
# Epoch 10/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 292.2559 - mse: 292.4736 - val_accuracy: 0.0000e+00 - val_loss: 377.7428 - val_mse: 386.5142
# Epoch 11/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 273.2242 - mse: 273.4363 - val_accuracy: 0.0000e+00 - val_loss: 356.2433 - val_mse: 364.7000
# Epoch 12/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 255.0081 - mse: 255.2146 - val_accuracy: 0.0000e+00 - val_loss: 335.5793 - val_mse: 343.7268
# Epoch 13/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 237.6058 - mse: 237.8069 - val_accuracy: 0.0000e+00 - val_loss: 315.7499 - val_mse: 323.5938
# Epoch 14/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 221.0159 - mse: 221.2115 - val_accuracy: 0.0000e+00 - val_loss: 296.7541 - val_mse: 304.2999
# Epoch 15/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 205.2364 - mse: 205.4267 - val_accuracy: 0.0000e+00 - val_loss: 278.5905 - val_mse: 285.8440
# Epoch 16/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 190.2652 - mse: 190.4503 - val_accuracy: 0.0000e+00 - val_loss: 261.2580 - val_mse: 268.2249
# Epoch 17/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 176.1001 - mse: 176.2800 - val_accuracy: 0.0000e+00 - val_loss: 244.7552 - val_mse: 251.4413
# Epoch 18/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 162.7385 - mse: 162.9133 - val_accuracy: 0.0000e+00 - val_loss: 229.0804 - val_mse: 235.4916
# Epoch 19/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 150.1772 - mse: 150.3470 - val_accuracy: 0.0000e+00 - val_loss: 214.2320 - val_mse: 220.3742
# Epoch 20/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 138.4130 - mse: 138.5778 - val_accuracy: 0.0000e+00 - val_loss: 200.2078 - val_mse: 206.0871
# Epoch 21/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 127.4417 - mse: 127.6016 - val_accuracy: 0.0000e+00 - val_loss: 187.0056 - val_mse: 192.6283
# Epoch 22/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 117.2586 - mse: 117.4139 - val_accuracy: 0.0000e+00 - val_loss: 174.6228 - val_mse: 179.9952
# Epoch 23/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 107.8584 - mse: 108.0090 - val_accuracy: 0.0000e+00 - val_loss: 163.0561 - val_mse: 168.1848
# Epoch 24/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 99.2345 - mse: 99.3805 - val_accuracy: 0.0000e+00 - val_loss: 152.3019 - val_mse: 157.1938
# Epoch 25/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 91.3790 - mse: 91.5205 - val_accuracy: 0.0000e+00 - val_loss: 142.3556 - val_mse: 147.0179
# Epoch 26/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 84.2823 - mse: 84.4195 - val_accuracy: 0.0000e+00 - val_loss: 133.2119 - val_mse: 137.6520
# Epoch 27/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 77.9329 - mse: 78.0658 - val_accuracy: 0.0000e+00 - val_loss: 124.8637 - val_mse: 129.0895
# Epoch 28/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 72.3162 - mse: 72.4450 - val_accuracy: 0.0000e+00 - val_loss: 117.3024 - val_mse: 121.3223
# Epoch 29/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 67.4141 - mse: 67.5390 - val_accuracy: 0.0000e+00 - val_loss: 110.5164 - val_mse: 114.3397
# Epoch 30/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 63.2041 - mse: 63.3252 - val_accuracy: 0.0000e+00 - val_loss: 104.4911 - val_mse: 108.1274
# Epoch 31/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 59.6573 - mse: 59.7749 - val_accuracy: 0.0000e+00 - val_loss: 99.2065 - val_mse: 102.6666
# Epoch 32/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 56.7379 - mse: 56.8520 - val_accuracy: 0.0000e+00 - val_loss: 94.6364 - val_mse: 97.9321
# Epoch 33/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 54.4008 - mse: 54.5119 - val_accuracy: 0.0000e+00 - val_loss: 90.7463 - val_mse: 93.8902
# Epoch 34/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 52.5913 - mse: 52.6996 - val_accuracy: 0.0000e+00 - val_loss: 87.4913 - val_mse: 90.4971
# Epoch 35/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 51.2449 - mse: 51.3506 - val_accuracy: 0.0000e+00 - val_loss: 84.8161 - val_mse: 87.6982
# Epoch 36/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 50.2891 - mse: 50.3926 - val_accuracy: 0.0000e+00 - val_loss: 82.6553 - val_mse: 85.4285
# Epoch 37/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.6479 - mse: 49.7495 - val_accuracy: 0.0000e+00 - val_loss: 80.9367 - val_mse: 83.6157
# Epoch 38/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 49.2470 - mse: 49.3469 - val_accuracy: 0.0000e+00 - val_loss: 79.5867 - val_mse: 82.1854
# Epoch 39/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0195 - mse: 49.1182 - val_accuracy: 0.0000e+00 - val_loss: 78.5350 - val_mse: 81.0662
# Epoch 40/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 48.9103 - mse: 49.0078 - val_accuracy: 0.0000e+00 - val_loss: 77.7192 - val_mse: 80.1943
# Epoch 41/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 48.8766 - mse: 48.9732 - val_accuracy: 0.0000e+00 - val_loss: 77.0868 - val_mse: 79.5156
# Epoch 42/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 48.8878 - mse: 48.9837 - val_accuracy: 0.0000e+00 - val_loss: 76.5954 - val_mse: 78.9863
# Epoch 43/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 48.9230 - mse: 49.0183 - val_accuracy: 0.0000e+00 - val_loss: 76.2119 - val_mse: 78.5718
# Epoch 44/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 48.9687 - mse: 49.0635 - val_accuracy: 0.0000e+00 - val_loss: 75.9108 - val_mse: 78.2456
# Epoch 45/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0168 - mse: 49.1112 - val_accuracy: 0.0000e+00 - val_loss: 75.6730 - val_mse: 77.9873
# Epoch 46/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0626 - mse: 49.1567 - val_accuracy: 0.0000e+00 - val_loss: 75.4837 - val_mse: 77.7815
# Epoch 47/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1038 - mse: 49.1977 - val_accuracy: 0.0000e+00 - val_loss: 75.3321 - val_mse: 77.6163
# Epoch 48/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1394 - mse: 49.2331 - val_accuracy: 0.0000e+00 - val_loss: 75.2096 - val_mse: 77.4829
# Epoch 49/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1692 - mse: 49.2627 - val_accuracy: 0.0000e+00 - val_loss: 75.1099 - val_mse: 77.3744
# Epoch 50/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1936 - mse: 49.2869 - val_accuracy: 0.0000e+00 - val_loss: 75.0282 - val_mse: 77.2854
# Epoch 51/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2129 - mse: 49.3062 - val_accuracy: 0.0000e+00 - val_loss: 74.9606 - val_mse: 77.2119
# Epoch 52/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2280 - mse: 49.3211 - val_accuracy: 0.0000e+00 - val_loss: 74.9042 - val_mse: 77.1507
# Epoch 53/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2392 - mse: 49.3322 - val_accuracy: 0.0000e+00 - val_loss: 74.8567 - val_mse: 77.0993
# Epoch 54/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2473 - mse: 49.3403 - val_accuracy: 0.0000e+00 - val_loss: 74.8162 - val_mse: 77.0557
# Epoch 55/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2527 - mse: 49.3456 - val_accuracy: 0.0000e+00 - val_loss: 74.7815 - val_mse: 77.0183
# Epoch 56/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2559 - mse: 49.3487 - val_accuracy: 0.0000e+00 - val_loss: 74.7513 - val_mse: 76.9860
# Epoch 57/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2572 - mse: 49.3500 - val_accuracy: 0.0000e+00 - val_loss: 74.7247 - val_mse: 76.9576
# Epoch 58/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2570 - mse: 49.3498 - val_accuracy: 0.0000e+00 - val_loss: 74.7011 - val_mse: 76.9325
# Epoch 59/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 49.2556 - mse: 49.3483 - val_accuracy: 0.0000e+00 - val_loss: 74.6798 - val_mse: 76.9100
# Epoch 60/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2531 - mse: 49.3459 - val_accuracy: 0.0000e+00 - val_loss: 74.6605 - val_mse: 76.8896
# Epoch 61/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2499 - mse: 49.3426 - val_accuracy: 0.0000e+00 - val_loss: 74.6427 - val_mse: 76.8709
# Epoch 62/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2459 - mse: 49.3386 - val_accuracy: 0.0000e+00 - val_loss: 74.6261 - val_mse: 76.8535
# Epoch 63/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2414 - mse: 49.3341 - val_accuracy: 0.0000e+00 - val_loss: 74.6105 - val_mse: 76.8373
# Epoch 64/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2365 - mse: 49.3291 - val_accuracy: 0.0000e+00 - val_loss: 74.5957 - val_mse: 76.8220
# Epoch 65/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2312 - mse: 49.3238 - val_accuracy: 0.0000e+00 - val_loss: 74.5816 - val_mse: 76.8074
# Epoch 66/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2256 - mse: 49.3182 - val_accuracy: 0.0000e+00 - val_loss: 74.5680 - val_mse: 76.7933
# Epoch 67/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2198 - mse: 49.3123 - val_accuracy: 0.0000e+00 - val_loss: 74.5548 - val_mse: 76.7798
# Epoch 68/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 49.2137 - mse: 49.3063 - val_accuracy: 0.0000e+00 - val_loss: 74.5420 - val_mse: 76.7666
# Epoch 69/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2076 - mse: 49.3001 - val_accuracy: 0.0000e+00 - val_loss: 74.5294 - val_mse: 76.7538
# Epoch 70/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.2013 - mse: 49.2938 - val_accuracy: 0.0000e+00 - val_loss: 74.5171 - val_mse: 76.7412
# Epoch 71/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 49.1949 - mse: 49.2874 - val_accuracy: 0.0000e+00 - val_loss: 74.5050 - val_mse: 76.7287
# Epoch 72/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1884 - mse: 49.2809 - val_accuracy: 0.0000e+00 - val_loss: 74.4930 - val_mse: 76.7165
# Epoch 73/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1819 - mse: 49.2743 - val_accuracy: 0.0000e+00 - val_loss: 74.4812 - val_mse: 76.7044
# Epoch 74/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1753 - mse: 49.2677 - val_accuracy: 0.0000e+00 - val_loss: 74.4694 - val_mse: 76.6924
# Epoch 75/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1686 - mse: 49.2611 - val_accuracy: 0.0000e+00 - val_loss: 74.4577 - val_mse: 76.6805
# Epoch 76/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1620 - mse: 49.2544 - val_accuracy: 0.0000e+00 - val_loss: 74.4461 - val_mse: 76.6687
# Epoch 77/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1553 - mse: 49.2477 - val_accuracy: 0.0000e+00 - val_loss: 74.4346 - val_mse: 76.6569
# Epoch 78/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 49.1486 - mse: 49.2409 - val_accuracy: 0.0000e+00 - val_loss: 74.4231 - val_mse: 76.6452
# Epoch 79/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1419 - mse: 49.2342 - val_accuracy: 0.0000e+00 - val_loss: 74.4116 - val_mse: 76.6335
# Epoch 80/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1351 - mse: 49.2275 - val_accuracy: 0.0000e+00 - val_loss: 74.4002 - val_mse: 76.6219
# Epoch 81/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1284 - mse: 49.2207 - val_accuracy: 0.0000e+00 - val_loss: 74.3888 - val_mse: 76.6103
# Epoch 82/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1216 - mse: 49.2139 - val_accuracy: 0.0000e+00 - val_loss: 74.3774 - val_mse: 76.5987
# Epoch 83/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1149 - mse: 49.2072 - val_accuracy: 0.0000e+00 - val_loss: 74.3660 - val_mse: 76.5871
# Epoch 84/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1081 - mse: 49.2004 - val_accuracy: 0.0000e+00 - val_loss: 74.3547 - val_mse: 76.5756
# Epoch 85/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.1014 - mse: 49.1936 - val_accuracy: 0.0000e+00 - val_loss: 74.3433 - val_mse: 76.5640
# Epoch 86/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0946 - mse: 49.1868 - val_accuracy: 0.0000e+00 - val_loss: 74.3320 - val_mse: 76.5525
# Epoch 87/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0878 - mse: 49.1801 - val_accuracy: 0.0000e+00 - val_loss: 74.3207 - val_mse: 76.5410
# Epoch 88/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 49.0811 - mse: 49.1733 - val_accuracy: 0.0000e+00 - val_loss: 74.3094 - val_mse: 76.5295
# Epoch 89/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0743 - mse: 49.1665 - val_accuracy: 0.0000e+00 - val_loss: 74.2981 - val_mse: 76.5180
# Epoch 90/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0676 - mse: 49.1597 - val_accuracy: 0.0000e+00 - val_loss: 74.2869 - val_mse: 76.5066
# Epoch 91/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 49.0608 - mse: 49.1530 - val_accuracy: 0.0000e+00 - val_loss: 74.2756 - val_mse: 76.4951
# Epoch 92/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0541 - mse: 49.1462 - val_accuracy: 0.0000e+00 - val_loss: 74.2643 - val_mse: 76.4836
# Epoch 93/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0473 - mse: 49.1395 - val_accuracy: 0.0000e+00 - val_loss: 74.2530 - val_mse: 76.4721
# Epoch 94/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0406 - mse: 49.1327 - val_accuracy: 0.0000e+00 - val_loss: 74.2418 - val_mse: 76.4607
# Epoch 95/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0339 - mse: 49.1259 - val_accuracy: 0.0000e+00 - val_loss: 74.2305 - val_mse: 76.4492
# Epoch 96/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 49.0271 - mse: 49.1192 - val_accuracy: 0.0000e+00 - val_loss: 74.2193 - val_mse: 76.4378
# Epoch 97/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0204 - mse: 49.1124 - val_accuracy: 0.0000e+00 - val_loss: 74.2081 - val_mse: 76.4264
# Epoch 98/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0136 - mse: 49.1057 - val_accuracy: 0.0000e+00 - val_loss: 74.1969 - val_mse: 76.4150
# Epoch 99/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0069 - mse: 49.0989 - val_accuracy: 0.0000e+00 - val_loss: 74.1856 - val_mse: 76.4036
# Epoch 100/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 49.0002 - mse: 49.0922 - val_accuracy: 0.0000e+00 - val_loss: 74.1744 - val_mse: 76.3922
# Epoch 101/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 48.9935 - mse: 49.0855 - val_accuracy: 0.0000e+00 - val_loss: 74.1632 - val_mse: 76.3807

# %% [markdown]
# ### 4.4 Plot the Training Results

# %%
def plot_loss(history):
    fig, ax = plt.subplots(1, 1, figsize=(20,5))
    ax.plot(history.history['loss'], 'g', label='Training Loss')
    ax.plot(history.history['val_loss'], 'b', label='Validation Loss')
    # Accuracy
    twax = plt.twinx()
    twax.plot(history.history['mse'], 'r', label='mse')
    plt.title('Training and Validation Loss and mse')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    ax.legend(loc='upper right')  # Add legend for training and validation loss
    twax.legend(loc='lower right')  # Add legend for mse
    plt.grid(True)

# %%
plot_loss(history)

# %%
# Last epoch loss
print(f"Last epoch training loss: {history.history['loss'][-1]:.2f}")
print(f"Last epoch validation loss: {history.history['val_loss'][-1]:.2f}")
# Out:
# Last epoch training loss: 54.53
# Last epoch validation loss: 74.16

# %% [markdown]
# The loss curves above are fairly typical. First, notice that there are two curves, one for the training loss and one for the validation loss. Both are large initially and then steadily decrease and eventually level off with no further improvement after about 30 epochs. Since the model is only trained on the training data, it is also fairly typical that the training loss is lower than the validation loss.

# %% [markdown]
# ### 4.4 Make Predictions using the Model
#
# We can now use the `predict()` method in Keras to make a single prediction. In this example, we pass a list of values to the model (representing the average number of rooms), and the model returns the predicted value for the price of a home for each input.

# %%
# Predict the median price of a home with [3, 4, 5, 6, 7] rooms.
x = np.array([3, 4, 5, 6, 7])
y_pred = model.predict(x)
for idx in range(len(x)):
    print("Predicted price of a home with {} rooms: ${}K".format(x[idx], int(y_pred[idx]*10)/10))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000208E8C7A020> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Predicted price of a home with 3 rooms: $11.9K
# Predicted price of a home with 4 rooms: $15.0K
# Predicted price of a home with 5 rooms: $18.2K
# Predicted price of a home with 6 rooms: $21.3K
# Predicted price of a home with 7 rooms: $24.5K
# C:\Users\valdez\AppData\Local\Temp\ipykernel_8392\334345502.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Predicted price of a home with {} rooms: ${}K".format(x[idx], int(y_pred[idx]*10)/10))

# %% [markdown]
# ### 4.5 Plot the Model and the Data

# %%
# Generate feature data that spans the range of interest for the independent variable.
x = np.linspace(3, 9, 10)

# Use the model to predict the dependent variable.
y = model.predict(x)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000208E8C7A020> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step

# %%
def plot_data(x_data, y_data, x, y, title=None):
    
    plt.figure(figsize=(15,5))
    plt.scatter(x_data, y_data, label='Ground Truth', color='green', alpha=0.5)
    plt.plot(x, y, color='k', label='Model Predictions')
    plt.xlim([3,9])
    plt.ylim([0,60])
    plt.xlabel('Average Number of Rooms')
    plt.ylabel('Price [$K]')
    plt.title(title)
    plt.grid(True)
    plt.legend()

# %%
plot_data(X_train_1d, y_train, x, y, title='Training Dataset')

# %%
plot_data(X_test_1d, y_test, x, y, title='Test Dataset')

# %% [markdown]
# ## 5 Conclusion

# %% [markdown]
# In this notebok, we introduced the topic of linear regression in the context of a simple neural network. We showed how Keras can be used to model and train the network to learn the parameters of the linear model and how to visualize the model predictions.
